# %%
import os
import yfinance as yf
import pandas as pd
import numpy as np
os.chdir('..')
from transformations.time_series import BasicTSTransformer,Indicators
from utils.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/7s/rqlglvnd5j59m1s85bx_4y3h0000gn/T/ipykernel_52154/1122246735.py in <module>
#       4 import numpy as np
#       5 #os.chdir('..')
# ----> 6 from transformations.time_series import BasicTSTransformer,Indicators
#
# ModuleNotFoundError: No module named 'transformations'

# %%
print(os.getcwd())
# Out:
# /Users/sinazabanfahm/FinAT/Strats

# %%
os.chdir('FinAT')

# %%
ticker = yf.Ticker('TSLA')
df = ticker.history('10y')

# %%
df.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-10-28 00:00:00-04:00  270.000000  273.540009  262.239990  262.510010
# 2024-10-29 00:00:00-04:00  264.510010  264.980011  255.509995  259.519989
# 2024-10-30 00:00:00-04:00  258.040009  263.350006  255.820007  257.549988
# 2024-10-31 00:00:00-04:00  257.989990  259.750000  249.250000  249.850006
# 2024-11-01 00:00:00-04:00  252.039993  254.000000  246.630005  248.979996
#
#                               Volume  Dividends  Stock Splits
# Date
# 2024-10-28 00:00:00-04:00  107653600        0.0           0.0
# 2024-10-29 00:00:00-04:00   80521800        0.0           0.0
# 2024-10-30 00:00:00-04:00   53993600        0.0           0.0
# 2024-10-31 00:00:00-04:00   66575300        0.0           0.0
# 2024-11-01 00:00:00-04:00   57424000        0.0           0.0

# %%
#df = pd.read_csv('DNN.csv')

# %%
BT = BasicTSTransformer()
Ind = Indicators()
ts_rets = BT.log_returns(df['Close'])

# %%
ts_rets.max()
# Out:
# 0.19818699146920774

# %%
es_2 = Ind.smoothed_rsi(ts_rets, 2)[30:] 
es_5 = Ind.smoothed_rsi(ts_rets, 5)[30:] - 50
es_10 = Ind.smoothed_rsi(ts_rets, 10)[30:] - 50
es_20 = Ind.smoothed_rsi(ts_rets, 20)[30:]- 50
es_30 = Ind.smoothed_rsi(ts_rets, 30)[30:] - 50
prices = df['Close']

# %%
import matplotlib.pyplot as plt
plt.plot(es_5,label = "5")
plt.plot(es_10, label = "10")
plt.plot(es_20, label = '20')
plt.plot(es_30,label = '30')
plt.plot(ts_rets, label = "rets DNN")
plt.legend()
plt.show()

# %%
plt.plot(es_20[100:], label = '20')

# %%
#Essentially we should get rid of the first 100: Distribution is not normal
es_20.hist(bins = 50, label = "es_20")
plt.legend()
plt.show()
es_20[100:].hist(bins = 50, label = "es_20- deleting first 130")
plt.legend()
plt.show()

# %%
es_2[100:].hist(bins = 50, label = "es_2")
plt.legend()
plt.show()

# %%
#Distribution is not normal - following transformation makes it normal - it is inverse logistic composed with some
#normalization
import numpy as np
es_2_transformed = - np.log(2/(1 + 0.0099* (2*es_2 -100))-1)

# %%
es_2_transformed[100:].hist(bins = 50)
# Out:
# <AxesSubplot:>

# %%
X = es_20[100:]
y = es_2_transformed[100:]
prices = prices[100:]

# %%
import torch
import torch.nn as nn
X = torch.tensor(np.array(X), dtype = torch.float32)
y = torch.tensor(np.array(y), dtype = torch.float32)
print(X.shape, y.shape)
# Out:
# torch.Size([1128]) torch.Size([1128])

# %%
split_size = 0.9
split_index = int(split_size * X.shape[0] )
X_train, X_test = X[:split_index].unsqueeze(1), X[split_index:].unsqueeze(1)
y_train, y_test = y[:split_index].unsqueeze(1), y[split_index:].unsqueeze(1)
prices_train, prices_test = prices[:split_index],prices[split_index:]

# %%
y_test.shape
# Out:
# torch.Size([113, 1])

# %%
class LinearRegression(nn.Module):
    def __init__(self, in_features, out_features):
        super(LinearRegression, self).__init__()
        self.linear = nn.Linear(in_features = in_features, out_features = out_features, bias = True)
        
    def forward(self,x):
        return self.linear(x)

# %%
model = LinearRegression(1,1)
model.linear.weight
# Out:
# Parameter containing:
# tensor([[0.1442]], requires_grad=True)

# %%
epochs = 1000
lr = 0.01
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = lr)

# %%
for epoch in range(epochs):
    optimizer.zero_grad()
    y_opt = model(X_train)
    loss = criterion(y_train, y_opt)
    if (epoch) % 100== 0:
        print(f"Epoch {epoch}/{epochs} | loss : {loss}")
    loss.backward()
    optimizer.step()
# Out:
# Epoch 0/1000 | loss : 0.7194013595581055
# Epoch 100/1000 | loss : 0.33209526538848877
# Epoch 200/1000 | loss : 0.3320924937725067
# Epoch 300/1000 | loss : 0.3320924937725067
# Epoch 400/1000 | loss : 0.3320924937725067
# Epoch 500/1000 | loss : 0.3320924937725067
# Epoch 600/1000 | loss : 0.3320924937725067
# Epoch 700/1000 | loss : 0.3320924937725067
# Epoch 800/1000 | loss : 0.3320924937725067
# Epoch 900/1000 | loss : 0.3320925235748291

# %%
model.linear.weight
# Out:
# Parameter containing:
# tensor([[0.4120]], requires_grad=True)

# %%
import matplotlib.pyplot as plt
plt.clf()
with torch.no_grad():
    predicted = model(X_test)
plt.plot(predicted, label = "predicted")
plt.plot(y_test, label = "true_vals")
plt.legend()
plt.show()
plt.plot(prices_test, label = "prices")

# %%
#Generate Signals:
def generate_signals(pred,actual):
    diff = actual - pred
    return diff.squeeze()

# %%
diff = generate_signals(predicted, (y_test))

# %%
diff
# Out:
# tensor([-0.2171, -0.2200, -0.3062,  0.1912, -0.3297, -0.1245, -0.4302, -0.0034,
#         -0.0318, -0.0192, -0.0494,  0.1960,  0.0065,  0.0456, -0.0124, -0.0622,
#          0.7126,  0.4123,  0.3515, -0.8101,  0.8497,  0.1611,  0.4683,  0.1004,
#          0.4755, -0.6714,  0.3710,  0.5899, -0.2892, -0.1291, -0.2759, -0.4560,
#          0.1092, -0.3522, -0.7366, -0.1595, -0.0974, -0.0852,  0.3917,  1.0701,
#          0.1537, -0.1919,  0.2892, -0.3246, -0.4426, -0.4702,  0.8297,  0.0161,
#          0.2234,  0.1523, -0.4044, -0.3864,  0.0031, -0.0218,  0.1093,  0.2693,
#         -0.2603, -0.2202, -0.2979, -0.8272,  0.4433, -0.6239,  0.4664, -0.2816,
#         -0.1029, -0.0989,  0.1751,  0.6237, -0.3603, -0.3858,  0.6824, -0.3335,
#         -0.1149, -0.8570, -0.2139,  0.3927, -0.5959,  0.1008, -0.5949, -0.4402,
#          0.0276,  0.1385,  0.1210,  0.7080,  1.3325,  0.2632,  0.2350,  1.3814,
#         -0.3111,  0.3410, -0.0828,  0.4594,  0.0138,  0.4848, -0.2896, -0.2989,
#         -0.3312,  1.0050, -0.3206, -0.3233,  0.3568, -0.1176,  0.0278, -0.0887,
#          0.1056,  0.2681, -0.4583,  0.0688, -0.4362,  0.2230, -0.0140, -0.0140,
#          0.1625])

# %%
diff = pd.DataFrame(predicted - y_test)
print(f"max: {diff.max()}")
print(f"min: {diff.min()}")
print(f"mean: {diff.mean()}")
print(f"std: {diff.std()}")
# Out:
# max: 0    0.857005
# dtype: float32
# min: 0   -1.381449
# dtype: float32
# mean: 0   -0.011955
# dtype: float32
# std: 0    0.428321
# dtype: float32

# %%
def buy_signal(diff, threshold = -0.3):
    return (diff < threshold)

# %%
signals = buy_signal(diff)

# %%
signals.sum()/signals.shape[0]
# Out:
# 0    0.212389
# dtype: float64

# %%
nbuys = int(signals.sum())

# %%
def generate_pnl(signals, price_vec):
    pnl = []
    for index in range(len(signals)-1):
        if signals[0][index]:
            pnl.append((price_vec[index+1]-price_vec[index])*1)
    return pnl

# %%
pnl = generate_pnl(signals,prices_test)

# %%
pnl
# Out:
# [-0.029999971389770508,
#  -0.07999998331069946,
#  -0.030000030994415283,
#  -0.04000002145767212,
#  0.17000001668930054,
#  -0.030000030994415283,
#  -0.020000040531158447,
#  0.0,
#  -0.039999961853027344,
#  -0.050000011920928955,
#  -0.030000030994415283,
#  -0.029999971389770508,
#  0.04000002145767212,
#  -0.050000011920928955,
#  -0.020000040531158447,
#  0.019999980926513672,
#  -0.009999990463256836,
#  0.02000001072883606,
#  0.030000001192092896,
#  -0.10999998450279236,
#  -0.04000002145767212,
#  -0.009999990463256836,
#  -0.019999980926513672,
#  0.009999990463256836]

# %%
tot = [0]
for p in pnl:
    tot.append((tot[-1]+p))
tot
# Out:
# [0,
#  -0.029999971389770508,
#  -0.10999995470046997,
#  -0.13999998569488525,
#  -0.18000000715255737,
#  -0.009999990463256836,
#  -0.04000002145767212,
#  -0.060000061988830566,
#  -0.060000061988830566,
#  -0.10000002384185791,
#  -0.15000003576278687,
#  -0.18000006675720215,
#  -0.21000003814697266,
#  -0.17000001668930054,
#  -0.2200000286102295,
#  -0.24000006914138794,
#  -0.22000008821487427,
#  -0.2300000786781311,
#  -0.21000006794929504,
#  -0.18000006675720215,
#  -0.2900000512599945,
#  -0.3300000727176666,
#  -0.34000006318092346,
#  -0.36000004410743713,
#  -0.3500000536441803]

# %%
plt.plot(tot)

# %%
ndays =y_test.shape[0]
ndays
# Out:
# 113

# %%
import random
index = [i for i in range(ndays)]
ind = random.sample(index,nbuys)

# %%
randomized_tot=[0]
for i in ind:
    if (i!=ndays):
        curr = prices_test[i+1] - prices_test[i]
        randomized_tot.append(randomized_tot[-1] + curr)

# %%
plt.plot(tot, label = "using smoothing")
plt.plot(randomized_tot, label = 'randomized')
plt.legend()
plt.show()
